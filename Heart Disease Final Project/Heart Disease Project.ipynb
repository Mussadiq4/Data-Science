# %% [markdown]
# # Final Project On Heart Disease DataSet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# # Histograms Of All the attributes(columns)

# %%
sns.set(font_scale=1)
data.hist(figsize=(20,20))
plt.show()

# %%
data.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
## Count Plot Of Target (0 - No heart disease , 1 - Heart Disease)

sns.countplot(x = "target" , data=data)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
data.sex.value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
## Count Plot Of Gender (0 - Female , 1 - Male)

sns.countplot(x='sex' , data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
data.groupby("sex")["target"].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %%
## Count Plot Of Target & Gender Both

sns.countplot(x = "sex" , hue = "target" , data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
data.groupby("age")["target"].value_counts()
# Out:
# age  target
# 29   1          4
# 34   1          6
# 35   1          8
#      0          7
# 37   1          6
#                ..
# 70   1          3
# 71   1         11
# 74   1          3
# 76   1          3
# 77   0          3
# Name: target, Length: 75, dtype: int64

# %%
## Count Plot Of Target & Age Both

plt.figure(figsize=(25,10))
sns.countplot(x = "age" , hue = "target" , data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
arr = list(data.columns)
print(arr)
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
arr.remove("target")
print(arr)
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %% [markdown]
# # BarPlots Of All the attributes(columns)

# %%
plt.figure(figsize=(20 , 20))

for i, col in enumerate(arr, 1):
    
    plt.subplot(4 , 4 , i)
    sns.barplot(x = col , y="target" , data = data)
    plt.ylabel("Possibility of having heart disease")
    plt.xlabel(col)

# %% [markdown]
# ## Now Applying Model

# %%
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
x = data.drop('target' , axis = 1)
y = data['target']

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (820, 13)
# (205, 13)
# (820,)
# (205,)

# %%
## Using Decision Tree Algorithm For training dataset

DT = DecisionTreeClassifier()
DT.fit(x_train , y_train)
y_pred = DT.predict(x_test)
acc = accuracy_score(y_test , y_pred)*100

print("Accuracy Score with the help of Decision Tree = " , acc)
# Out:
# Accuracy Score with the help of Decision Tree =  98.53658536585365

# %%
## Using Random Forest Algorithm For training dataset

RT = RandomForestClassifier()
RT.fit(x_train , y_train)
y_pred = RT.predict(x_test)
acc = accuracy_score(y_test , y_pred)*100

print("Accuracy Score with the help of Random Forest = " , acc)
# Out:
# Accuracy Score with the help of Random Forest =  100.0

# %% [markdown]
# ## Confusion Matrix

# %%
conf = confusion_matrix(y_test , y_pred)
sns.heatmap(conf)
plt.show()
